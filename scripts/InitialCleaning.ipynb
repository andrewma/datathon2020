# %%
import pandas as pd
import numpy as np

# %%
dfs = []
for i in range(0, 6):
    cur = pd.read_csv("data/%d.csv" % i)
    if not i == 0:
        cur = cur.drop(0)
    dfs.append(cur)
all_data = pd.concat(dfs, ignore_index=True)
all_data = all_data.reset_index()
# Out:
# /Users/lutton/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (1,5,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
price_estimates = {
    'Establishments operated entire year with sales/receipts/revenue of $100,000 to $249,999': (249999+100000)/2,
    'Establishments operated entire year with sales/receipts/revenue of $250,000 to $499,999': (499999+250000)/2,
    'Establishments operated entire year with sales/receipts/revenue of $500,000 to $999,999': (999999+500000)/2,
    'Establishments operated entire year with sales/receipts/revenue of $1,000,000 or more': 1500000
}


cleaned_list = []
for i in range(1, len(all_data)):
    zipCode = all_data.at[i, 'GEO.id2']
    industry = all_data.at[i, 'NAICS.display-label']
    estabDisplay = all_data.at[i, 'RCPSZFE.display-label']
    estabs = all_data.at[i, 'ESTAB']
    
    if i % 100000 == 0:
        print(i)
    most_recent = []
    if len(cleaned_list) >= 1:
        most_recent = cleaned_list[len(cleaned_list) - 1]
    if not most_recent == [] and most_recent[0] == zipCode and most_recent[1] == industry:
        most_recent[2] += price_estimates.get(estabDisplay, 0) * int(estabs)
    else:
        cleaned_list.append([zipCode, industry, price_estimates.get(estabDisplay, 0) * int(estabs)])

cleaned_data = pd.DataFrame(cleaned_list, columns = ['ZIP', 'NAIC', 'EST_SALES'])

# %%
cleaned_data.to_csv('data/cleaned.csv')

# %%
cleaned_data = pd.read_csv('data/cleaned.csv')

# %%
#all_data.at[1155997, 'ESTAB']

# %%
C = pow(np.pi, 2)/pow(np.e, 2)
def f(x, m):
    sum = 0
    for i in range(len(x)):
        sum += (1 - pow(C, -(x[i])/((0.08*m[i]))))*m[i]
    return -sum

# %%
C = 4
lnc = np.log(C)
n = 3
def f_taylor(x, m):
    sum = 0
    for i in range(len(x)):
        fac = 1
        for j in range(1, n):
            fac *= j
            sum += (-1) * m[i] * pow(- 1/(0.08 * m[i]), j) * pow(lnc, j) * pow(x[i], j) * (1/fac)
    return -sum

# %%
used_data = cleaned_data[cleaned_data["NAIC"] == 'Retail trade'].nlargest(1000, 'EST_SALES')
# training = cleaned_data.sample(n = 1000)
# validation = cleaned_data.sample(frac = 0.2)
# verification = cleaned_data.sample(frac = 0.2)

# %%
used_data
# Out:
#         Unnamed: 0    ZIP          NAIC    EST_SALES
# 478290      478290  89109  Retail trade  844574891.0
# 494209      494209   7652  Retail trade  602799901.0
# 511014      511014  10012  Retail trade  597699891.0
# 511701      511701  10022  Retail trade  581199908.0
# 511102      511102  10013  Retail trade  551824815.0
# 510340      510340  10001  Retail trade  534949858.0
# 376996      376996  21401  Retail trade  517899884.0
# 512614      512614  10036  Retail trade  514574882.0
# 705189      705189  29607  Retail trade  513074907.0
# 793602      793602  78216  Retail trade  490324927.5
# 147790      147790  92626  Retail trade  480824935.0
# 28968        28968  32819  Retail trade  478649924.0
# 163706      163706  94103  Retail trade  466224909.0
# 511625      511625  10021  Retail trade  464249907.5
# 510934      510934  10011  Retail trade  459674904.0
# 801116      801116  78666  Retail trade  446524927.5
# 704483      704483  29577  Retail trade  442174893.0
# ...

# %%
B = 10000000
weights = used_data['EST_SALES'].values.tolist()
weights = list(filter(lambda num: num != 0, weights))
ones = [1 for i in range(len(weights))]
lower = [0.1 for i in range(len(weights))]
upper = [B for i in range(len(weights))]

# %%
import scipy
from scipy import optimize
from scipy.optimize import LinearConstraint
from scipy.optimize import Bounds
linear_constraint = LinearConstraint([ones], 0, B, keep_feasible=True)
bounds = Bounds(lower, upper, keep_feasible=True)

result = scipy.optimize.minimize(method='SLSQP', fun=f, args=(weights), x0=ones, constraints=(linear_constraint),
                       options={'maxiter': 50, 'disp': True, 'eps': B*(1/100)}, bounds=(bounds))
# Out:
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: -173220857.91075292
#             Iterations: 51
#             Function evaluations: 50461
#             Gradient evaluations: 50

# %%
retail_zips = pd.DataFrame({"ZIP": used_data['ZIP'], "MONEY": result['x']})
retail_zips
# Out:
#           ZIP         MONEY
# 478290  89109  14885.931987
# 494209   7652  14203.672362
# 511014  10012  14183.344247
# 511701  10022  14115.136119
# 511102  10013  13983.623842
# 510340  10001  13901.552539
# 376996  21401  13813.206474
# 512614  10036  13795.296514
# 705189  29607  13787.141109
# 793602  78216  13657.341231
# 147790  92626  13599.509571
# 28968   32819  13585.946663
# 163706  94103  13506.044684
# 511625  10021  13492.950692
# 510934  10011  13462.187578
# 801116  78666  13370.261074
# 704483  29577  13338.650254
# 285775  60611  13330.742815
# 338617  96814  13235.690427
# 511495  10019  13192.776830
# 778659  77056  13185.551284
# 338706  96815  13163.891603
# 753270  75034  13153.471158
# 183343  95678  13122.659391
# 716953  37421  13070.561660
# 37463   33172  13036.924010
# 28527   32809  13034.512252
# 113584  85705  13007.320645
# 797462  78501  12963.349295
# 379016  21740  12961.750925
# ...       ...           ...
# 318260  70065   7952.402229
# ...

# %%
retail_zips.to_csv("retails_zips.csv")

# %%
r = [22.25102429, 22.07078002, 22.06543901, 22.04753037, 22.01305446,
       22.00417605, 21.99157533, 21.96848476, 21.9638076 , 21.96167826,
       21.92782458, 21.91276332, 21.90923307, 21.88845072, 21.88504747,
       21.87705458, 21.85963054, 21.85319305, 21.84499567, 21.84294573,
       21.81832394, 21.80721983, 21.80535091, 21.79974981, 21.7970558 ,
       21.78909256, 21.7756367 , 21.76695454, 21.76633222, 21.75931744,
       21.74798016, 21.7475682 , 21.74526621, 21.74098738, 21.72373297,
       21.7101291 , 21.69372096, 21.68471219, 21.68129255, 21.67900009,
       21.668901  , 21.66000568, 21.65775796, 21.6574763 , 21.65088562,
       21.63978848, 21.63869524, 21.63267854, 21.62838193, 21.62763765,
       21.62412574, 21.62179705, 21.61938265, 21.61870166, 21.61482658,
       20.63075836, 20.62993373, 20.62938351, 20.62745616, 20.62607729,
       20.62607723, 20.62607711, 20.62469635, 20.62359044, 20.62359028,
       20.62331373, 20.62137519, 20.62137499, 20.62109774, 20.6208205 ,
       20.61998791, 20.61943257, 20.61832114, 20.61832095, 20.61748667,
       20.61693008, 20.6169299 , 20.6166517 , 20.61218643, 20.61218638,
       20.61078708, 20.60966638, 20.60938601, 20.60882485, 20.60854442,
       20.60770212, 20.60629704, 20.60573436, 20.60573436, 20.60488985,
       20.60488978, 20.60488974, 20.60460813, 20.60319876, 20.6026344 ,
       20.60093985, 20.6000916 , 20.60009136, 20.59924248, 20.59895933,
       20.59810932, 20.59782574, 20.59640739, 20.59555525, 20.5944184 ,
       20.59242545, 20.5921405 , 20.59185548, 20.59157023, 20.59071443,
       20.59042895, 20.5898578 , 20.58842864, 20.58814263, 20.58785647,
       20.5855645 , 20.58556435, 20.583555  , 20.58269276, 20.58269265,
       20.58211727, 20.58211686, 20.58096563, 20.58096563, 20.58010085,
       20.57981297, 20.57981286, 20.57923596, 20.57894752, 20.57750361,
       20.57489957, 20.57228936, 20.57083631, 20.57083622, 20.57054544,
       20.56909014, 20.56763278, 20.56734113, 20.56675743, 20.56646541,
       20.56617385, 20.5655886 , 20.56295624, 20.56178363, 20.56031654,
       20.56002278, 20.55825895, 20.55649228, 20.55619748, 20.55206252,
       20.55117457, 20.54909948, 20.54880276, 20.54434153, 20.54195468,
       20.54195467, 20.53926334, 20.53896345, 20.53866381, 20.53776496,
       20.53746514, 20.53626488, 20.5362647 , 20.5356641 , 20.53446176,
       20.53416093, 20.53385958, 20.53355907, 20.53355888, 20.53265591,
       20.52963903, 20.52933686, 20.52752247, 20.52752238, 20.52691704,
       20.52661413, 20.5266141 , 20.52509849, 20.52479504, 20.52479487,
       20.52297291, 20.5229729 , 20.52236493, 20.52114789, 20.52053878,
       20.52053866, 20.52023408, 20.51992926, 20.51962461, 20.51962448,
       20.51931974, 20.51840434, 20.5184043 , 20.5180993 , 20.51809916,
       20.51809908, 20.518099  , 20.51687723, 20.51565426, 20.51534814]

# %%
[f(r, weights), f_taylor(r, weights)]
# Out:
# [-76081.96456592972, -76081.96456571209]

# %%
import time
start_time = time.time()
for i in range(10000):
    a = f_taylor(r, weights)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 26.501569986343384 seconds ---

# %%
cleaned_data
# Out:
#         Unnamed: 0    ZIP                                               NAIC  \
# 0                0   6001                                       Retail trade
# 1                1   6001                    Motor vehicle and parts dealers
# 2                2   6001                                 Automobile dealers
# 3                3   6001                                    New car dealers
# 4                4   6001     Automotive parts, accessories, and tire stores
# 5                5   6001                                       Tire dealers
# 6                6   6001              Furniture and home furnishings stores
# 7                7   6001                                   Furniture stores
# 8                8   6001                            Home furnishings stores
# 9                9   6001                              Floor covering stores
# 10              10   6001                      Other home furnishings stores
# ...

# %%
used_data
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ZIP, NAIC, EST_SALES]
# Index: []
