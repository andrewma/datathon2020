# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
tax_df = pd.read_csv("2012taxInfo.csv")

# %%
tax_df
# Out:
#         STATEFIPS STATE  zipcode  AGI_STUB      N1   MARS1   MARS2   MARS4  \
# 0               1    AL        0         1  889920  490850  129070  256900
# 1               1    AL        0         2  491150  194370  159200  123350
# 2               1    AL        0         3  254280   68160  148960   31480
# 3               1    AL        0         4  160160   23020  126140    9030
# 4               1    AL        0         5  183320   15880  161260    4890
# ...           ...   ...      ...       ...     ...     ...     ...     ...
# 166899         56    WY    99999         2    6070    3330    1710     890
# 166900         56    WY    99999         3    3720    1550    1810     310
# 166901         56    WY    99999         4    2590     660    1780     140
# 166902         56    WY    99999         5    2960     470    2400      80
# 166903         56    WY    99999         6    1070     210     860      40
#
# ...

# %%
zipToCounty_df = pd.read_csv("zipToCounty.csv")

# %%
zipToCounty_df
# Out:
#          ZIP         COUNTYNAME STATE  STCOUNTYFP CLASSFP
# 0      36003            Autauga    AL        1001      H1
# 1      36006            Autauga    AL        1001      H1
# 2      36067            Autauga    AL        1001      H1
# 3      36066            Autauga    AL        1001      H1
# 4      36703            Autauga    AL        1001      H1
# ...      ...                ...   ...         ...     ...
# 52884    850   St. Croix Island    VI       78010      H4
# 52885    840   St. Croix Island    VI       78010      H4
# 52886    820   St. Croix Island    VI       78010      H4
# 52887    830    St. John Island    VI       78020      H4
# 52888    802  St. Thomas Island    VI       78030      H4
#
# [52889 rows x 5 columns]

# %%
cleaned_df = pd.read_csv("cleaned.csv")

# %%
cleaned_df
# Out:
#         Unnamed: 0    ZIP                                            NAIC  \
# 0                0   6001                                    Retail trade
# 1                1   6001                 Motor vehicle and parts dealers
# 2                2   6001                              Automobile dealers
# 3                3   6001                                 New car dealers
# 4                4   6001  Automotive parts, accessories, and tire stores
# ...            ...    ...                                             ...
# 839044      839044  99403       Electronic shopping and mail-order houses
# 839045      839045  99403                             Electronic shopping
# 839046      839046  99403                   Direct selling establishments
# 839047      839047  99403                                    Fuel dealers
# 839048      839048  99403             Other direct selling establishments
#
#          EST_SALES
# 0       72699984.0
# 1        3000000.0
# ...

# %%
#x = zipToCounty_df[zipToCounty_df["COUNTYNAME"] == "Autauga County"]
#x = zipToCounty_df["ZIP"]

#for index, row in zipToCounty_df.iterrows():
#        print(row["ZIP"])

# %%
zTc = zipToCounty_df.set_index('ZIP')['COUNTYNAME'].to_dict()

# %%
zTc
# Out:
# {36003: 'Autauga',
#  36006: 'Chilton',
#  36067: 'Elmore',
#  36066: 'Elmore',
#  36703: 'Dallas',
#  36701: 'Perry',
#  36091: 'Chilton',
#  36051: 'Elmore',
#  36068: 'Autauga',
#  36008: 'Autauga',
#  36022: 'Elmore',
#  36749: 'Dallas',
#  36758: 'Dallas',
#  36550: 'Baldwin',
#  36551: 'Baldwin',
#  36527: 'Baldwin',
#  36577: 'Baldwin',
#  36559: 'Baldwin',
#  36536: 'Baldwin',
#  36576: 'Baldwin',
#  36579: 'Baldwin',
#  36502: 'Monroe',
#  36578: 'Baldwin',
#  36533: 'Baldwin',
#  36564: 'Baldwin',
#  36561: 'Baldwin',
#  36580: 'Baldwin',
#  36535: 'Baldwin',
#  36547: 'Baldwin',
#  36549: 'Baldwin',
#  36530: 'Baldwin',
#  36562: 'Escambia',
#  36532: 'Baldwin',
#  36526: 'Baldwin',
#  36555: 'Baldwin',
#  36511: 'Baldwin',
#  36567: 'Baldwin',
#  36574: 'Baldwin',
#  36480: 'Monroe',
#  36507: 'Baldwin',
#  36542: 'Baldwin',
#  36017: 'Barbour',
#  36016: 'Barbour',
#  36311: 'Dale',
#  36374: 'Dale',
#  36048: 'Barbour',
#  36053: 'Bullock',
#  36317: 'Henry',
# ...

# %%
cleaned_df['County'] = cleaned_df.ZIP.replace(zTc)

# %%
zTf = zipToCounty_df.set_index('ZIP')['STCOUNTYFP'].to_dict()

# %%
zTf
# Out:
# {36003: 1001,
#  36006: 1021,
#  36067: 1051,
#  36066: 1051,
#  36703: 1047,
#  36701: 1105,
#  36091: 1021,
#  36051: 1051,
#  36068: 1001,
#  36008: 1001,
#  36022: 1051,
#  36749: 1047,
#  36758: 1047,
#  36550: 1003,
#  36551: 1003,
#  36527: 1003,
#  36577: 1003,
#  36559: 1003,
#  36536: 1003,
#  36576: 1003,
#  36579: 1003,
#  36502: 1099,
#  36578: 1003,
#  36533: 1003,
#  36564: 1003,
#  36561: 1003,
#  36580: 1003,
#  36535: 1003,
#  36547: 1003,
#  36549: 1003,
#  36530: 1003,
#  36562: 1053,
#  36532: 1003,
#  36526: 1003,
#  36555: 1003,
#  36511: 1003,
#  36567: 1003,
#  36574: 1003,
#  36480: 1099,
#  36507: 1003,
#  36542: 1003,
#  36017: 1005,
#  36016: 1005,
#  36311: 1045,
#  36374: 1045,
#  36048: 1005,
#  36053: 1011,
#  36317: 1067,
#  36027: 1113,
#  36072: 1005,
#  35035: 1117,
#  35034: 1007,
#  36750: 1021,
#  35115: 1117,
#  35188: 1125,
#  36793: 1021,
#  35074: 1007,
#  35042: 1105,
#  35111: 1125,
#  35184: 1125,
#  36792: 1021,
#  35456: 1125,
# ...

# %%
cleaned_df['FIPS'] = cleaned_df.ZIP.replace(zTf)

# %%
cleaned_df
# Out:
#         Unnamed: 0    ZIP                                            NAIC  \
# 0                0   6001                                    Retail trade
# 1                1   6001                 Motor vehicle and parts dealers
# 2                2   6001                              Automobile dealers
# 3                3   6001                                 New car dealers
# 4                4   6001  Automotive parts, accessories, and tire stores
# ...            ...    ...                                             ...
# 839044      839044  99403       Electronic shopping and mail-order houses
# 839045      839045  99403                             Electronic shopping
# 839046      839046  99403                   Direct selling establishments
# 839047      839047  99403                                    Fuel dealers
# 839048      839048  99403             Other direct selling establishments
#
#          EST_SALES    County   FIPS
# 0       72699984.0  Hartford   9003
# ...

# %%
#cleaned_df.to_csv('newcleaned.csv')

# %%
election_df = pd.read_csv('2012ElectionData.csv')

# %%
election_df
# Out:
#       year    state state_po       county    FIPS     office     candidate  \
# 0     2012  Alabama       AL      Autauga  1001.0  President  Barack Obama
# 1     2012  Alabama       AL      Autauga  1001.0  President   Mitt Romney
# 2     2012  Alabama       AL      Autauga  1001.0  President         Other
# 3     2012  Alabama       AL      Baldwin  1003.0  President  Barack Obama
# 4     2012  Alabama       AL      Baldwin  1003.0  President   Mitt Romney
# ...    ...      ...      ...          ...     ...        ...           ...
# 9469  2012   Alaska       AK  District 40  2040.0  President   Mitt Romney
# 9470  2012   Alaska       AK  District 40  2040.0  President         Other
# 9471  2012   Alaska      NaN  District 99  2099.0  President  Barack Obama
# 9472  2012   Alaska      NaN  District 99  2099.0  President   Mitt Romney
# 9473  2012   Alaska      NaN  District 99  2099.0  President         Other
#
# ...

# %%
fipsToParty = election_df.set_index('FIPS')['PartyWon'].to_dict()

# %%
cleaned_df['politicalParty'] = cleaned_df.FIPS.replace(fipsToParty)

# %%
cleaned_df
# Out:
#         Unnamed: 0    ZIP                                            NAIC  \
# 0                0   6001                                    Retail trade
# 1                1   6001                 Motor vehicle and parts dealers
# 2                2   6001                              Automobile dealers
# 3                3   6001                                 New car dealers
# 4                4   6001  Automotive parts, accessories, and tire stores
# ...            ...    ...                                             ...
# 839044      839044  99403       Electronic shopping and mail-order houses
# 839045      839045  99403                             Electronic shopping
# 839046      839046  99403                   Direct selling establishments
# 839047      839047  99403                                    Fuel dealers
# 839048      839048  99403             Other direct selling establishments
#
#          EST_SALES    County   FIPS politicalParty
# ...

# %%
zipToAgi = tax_df.set_index('zipcode')['A00100'].to_dict()

# %%
cleaned_df['AGI'] = cleaned_df.ZIP.replace(zipToAgi)

# %%
cleaned_df
# Out:
#         Unnamed: 0    ZIP                                            NAIC  \
# 0                0   6001                                    Retail trade
# 1                1   6001                 Motor vehicle and parts dealers
# 2                2   6001                              Automobile dealers
# 3                3   6001                                 New car dealers
# 4                4   6001  Automotive parts, accessories, and tire stores
# ...            ...    ...                                             ...
# 839044      839044  99403       Electronic shopping and mail-order houses
# 839045      839045  99403                             Electronic shopping
# 839046      839046  99403                   Direct selling establishments
# 839047      839047  99403                                    Fuel dealers
# 839048      839048  99403             Other direct selling establishments
#
#          EST_SALES    County   FIPS politicalParty      AGI
# ...

# %%
zipPop_df = df.read_csv('FRED_countyPop.csv')

# %%
cleaned_df
# Out:
#         Unnamed: 0    ZIP                                            NAIC  \
# 0                0   6001                                    Retail trade
# 1                1   6001                 Motor vehicle and parts dealers
# 2                2   6001                              Automobile dealers
# 3                3   6001                                 New car dealers
# 4                4   6001  Automotive parts, accessories, and tire stores
# ...            ...    ...                                             ...
# 839044      839044  99403       Electronic shopping and mail-order houses
# 839045      839045  99403                             Electronic shopping
# 839046      839046  99403                   Direct selling establishments
# 839047      839047  99403                                    Fuel dealers
# 839048      839048  99403             Other direct selling establishments
#
#          EST_SALES    County   FIPS politicalParty      AGI
# ...

# %%
zipToState = zipToCounty_df.set_index('ZIP')['STATE'].to_dict()

# %%
cleaned_df['STATE'] = pd.merge(, df2, how='inner', left_on='UniqueID', right_on='ID')

# %%
zipToState
# Out:
# {36003: 'AL',
#  36006: 'AL',
#  36067: 'AL',
#  36066: 'AL',
#  36703: 'AL',
#  36701: 'AL',
#  36091: 'AL',
#  36051: 'AL',
#  36068: 'AL',
#  36008: 'AL',
#  36022: 'AL',
#  36749: 'AL',
#  36758: 'AL',
#  36550: 'AL',
#  36551: 'AL',
#  36527: 'AL',
#  36577: 'AL',
#  36559: 'AL',
#  36536: 'AL',
#  36576: 'AL',
#  36579: 'AL',
#  36502: 'AL',
#  36578: 'AL',
#  36533: 'AL',
#  36564: 'AL',
#  36561: 'AL',
#  36580: 'AL',
#  36535: 'AL',
#  36547: 'AL',
#  36549: 'AL',
#  36530: 'AL',
#  36562: 'AL',
#  36532: 'AL',
#  36526: 'AL',
#  36555: 'AL',
#  36511: 'AL',
#  36567: 'AL',
#  36574: 'AL',
#  36480: 'AL',
#  36507: 'AL',
#  36542: 'AL',
#  36017: 'AL',
#  36016: 'AL',
#  36311: 'AL',
#  36374: 'AL',
#  36048: 'AL',
#  36053: 'AL',
#  36317: 'AL',
#  36027: 'AL',
#  36072: 'AL',
#  35035: 'AL',
#  35034: 'AL',
#  36750: 'AL',
#  35115: 'AL',
#  35188: 'AL',
#  36793: 'AL',
#  35074: 'AL',
#  35042: 'AL',
#  35111: 'AL',
#  35184: 'AL',
#  36792: 'AL',
#  35456: 'AL',
# ...

# %%
cleaned_df['State'] = cleaned_df.ZIP.replace(zipToState)

# %%
countyPop = pd.read_csv('FRED_countyPop.csv')

# %%
cleaned_df
# Out:
#         Unnamed: 0    ZIP                                            NAIC  \
# 0                0   6001                                    Retail trade
# 1                1   6001                 Motor vehicle and parts dealers
# 2                2   6001                              Automobile dealers
# 3                3   6001                                 New car dealers
# 4                4   6001  Automotive parts, accessories, and tire stores
# ...            ...    ...                                             ...
# 839044      839044  99403       Electronic shopping and mail-order houses
# 839045      839045  99403                             Electronic shopping
# 839046      839046  99403                   Direct selling establishments
# 839047      839047  99403                                    Fuel dealers
# 839048      839048  99403             Other direct selling establishments
#
#          EST_SALES    County   FIPS politicalParty      AGI State
# ...

# %%
zipCodePopulation_df = pd.read_csv('2010census.csv')

# %%
zipCodePopulation_df
# Out:
#        ZipCode  2010 Census Population
# 0         1001                   16769
# 1         1002                   29049
# 2         1003                   10372
# 3         1005                    5079
# 4         1007                   14649
# ...        ...                     ...
# 33087    99923                      87
# 33088    99925                     819
# 33089    99926                    1460
# 33090    99927                      94
# 33091    99929                    2338
#
# [33092 rows x 2 columns]

# %%
zipToPop = zipCodePopulation_df.set_index('ZipCode')['2010 Census Population'].to_dict()

# %%
cleaned_df['Population'] = cleaned_df.ZIP.replace(zipToPop)

# %%
cleaned_df
# Out:
#         Unnamed: 0    ZIP                                            NAIC  \
# 0                0   6001                                    Retail trade
# 1                1   6001                 Motor vehicle and parts dealers
# 2                2   6001                              Automobile dealers
# 3                3   6001                                 New car dealers
# 4                4   6001  Automotive parts, accessories, and tire stores
# ...            ...    ...                                             ...
# 839044      839044  99403       Electronic shopping and mail-order houses
# 839045      839045  99403                             Electronic shopping
# 839046      839046  99403                   Direct selling establishments
# 839047      839047  99403                                    Fuel dealers
# 839048      839048  99403             Other direct selling establishments
#
#          EST_SALES    County   FIPS politicalParty      AGI State  Population
# ...

# %%
zipBusinessData2012 = pd.read_csv('zipbusiness2012data.csv')

# %%
zipBusinessData2012
# Out:
#                 zip name  empflag emp_nf       emp qp1_nf        qp1   ap_nf  \
# 501      HOLTSVILLE   NY        A      D         0      D          0       D
# 1001         AGAWAM   MA        G   9033         G  84256          G  356861
# 1002        AMHERST   MA        H  16422         G  90914          G  378362
# 1003        AMHERST   MA        G    199         G   2003          G    8009
# 1004        AMHERST   MA        H    161         H   1140          H    5107
# ...             ...  ...      ...    ...       ...    ...        ...     ...
# 99927   POINT BAKER   AK        A      D         0      D          0       D
# 99928     WARD COVE   AK        B      D         0      D          0       D
# 99929      WRANGELL   AK        H    545         G   4189          G   20213
# 99950     KETCHIKAN   AK        B      D         0      D          0       D
# 99999  UNCLASSIFIED    G  2733406      G  34454160      G  137984844   16465
#
# ...

# %%
zipBusinessData2013 = pd.read_csv('zipBusinessData2013.csv')

# %%
zipBusinessData2013
# Out:
#                 zip name  empflag emp_nf       emp qp1_nf        qp1   ap_nf  \
# 501      HOLTSVILLE   NY        A      D         0      D          0       D
# 1001         AGAWAM   MA        G   9418         G  92083          G  373116
# 1002        AMHERST   MA        H  17263         G  95047          G  398992
# 1003        AMHERST   MA        G    184         H   1754          H    7181
# 1004        AMHERST   MA        H    179         H   1168          H    5019
# ...             ...  ...      ...    ...       ...    ...        ...     ...
# 99927   POINT BAKER   AK        G      3         S      0          H      64
# 99928     WARD COVE   AK        B      D         0      D          0       D
# 99929      WRANGELL   AK        H    524         G   4364          G   19045
# 99950     KETCHIKAN   AK        B      D         0      D          0       D
# 99999  UNCLASSIFIED    G  3071633      G  40216416      G  161671467   18254
#
# ...

# %%
len(zipBusinessData2012)
# Out:
# 38818

# %%
len(zipBusinessData2013)
# Out:
# 38804

# %%
#zipBusinessData2017 = pd.read_csv('zipBusinessData2017.csv')

# %%
zipBusinessData2017
# Out:
#       zip,name,empflag,emp_nf,emp,qp1_nf,qp1,ap_nf,ap,est,city,stabbr,cty_name
# 0      01001,AGAWAM, MA,G,9891,G,96616,G,422470,473,A...
# 1      01002,AMHERST, MA,H,8482,H,70277,H,299103,545,...
# 2      01003,AMHERST, MA,G,337,H,2461,H,10380,21,AMHE...
# 3      01004,AMHERST, MA,H,213,H,1422,H,5912,12,AMHER...
# 4      01005,BARRE, MA,H,1248,H,8163,H,35287,94,BARRE...
# ...                                                  ...
# 35274  99926,METLAKATLA, AK,J,88,J,587,J,5940,11,METL...
# 35275  99928,WARD COVE, AK,J,17,G,110,H,850,5,WARD CO...
# 35276  99929,WRANGELL, AK,G,662,G,6454,G,22974,99,WRA...
# 35277  99950,KETCHIKAN, AK,G,40,J,122,H,744,13,KETCHI...
# 35278  99999,UNCLASSIFIED,G,5400648,G,69733478,G,2764...
#
# [35279 rows x 1 columns]

# %%
cleaned_df
# Out:
#         Unnamed: 0    ZIP                                            NAIC  \
# 0                0   6001                                    Retail trade
# 1                1   6001                 Motor vehicle and parts dealers
# 2                2   6001                              Automobile dealers
# 3                3   6001                                 New car dealers
# 4                4   6001  Automotive parts, accessories, and tire stores
# ...            ...    ...                                             ...
# 839044      839044  99403       Electronic shopping and mail-order houses
# 839045      839045  99403                             Electronic shopping
# 839046      839046  99403                   Direct selling establishments
# 839047      839047  99403                                    Fuel dealers
# 839048      839048  99403             Other direct selling establishments
#
#          EST_SALES    County   FIPS politicalParty      AGI State  Population
# ...

# %%
cleaned_df.to_csv('cleaned2.0.csv')
